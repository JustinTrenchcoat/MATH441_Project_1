# %%
import numpy as np
import cvxpy as cp
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import cvxpy as cp
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'

# %%
aoe = pd.read_excel("aoe4_data.xlsx", index_col=0)
aoe = aoe.drop('Note', axis=1)
aoe.head()
# Out:
#                      Unnamed: 1 Unnamed: 2  Resource Cost  Unnamed: 4  \
#
# Name                        Civ        Age            NaN         NaN
# Light Melee Infantry        NaN        NaN            NaN         NaN
# Spearman                    All          I           60.0        20.0
# NaN                         NaN         II            NaN         NaN
# NaN                         NaN        III            NaN         NaN
#
#                       Unnamed: 5 Unnamed: 6  Time  Pop  Move     HP  \
#
# Name                         NaN      Total   NaN  NaN   NaN    NaN
# Light Melee Infantry         NaN        NaN   NaN  NaN   NaN    NaN
# Spearman                     0.0         80  15.0  1.0  1.25   70.0
# NaN                          NaN        NaN   NaN  NaN   NaN   90.0
# NaN                          NaN        NaN   NaN  NaN   NaN  110.0
#
#                      HP per\nResource  Armor Unnamed: 13 Attack Unnamed: 15  \
#
# ...

# %%
aoe_data = pd.read_csv
